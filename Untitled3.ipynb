# %% [markdown]
# <a href="https://colab.research.google.com/github/aqdassajid/Expense-Tracker/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Circle Detection in Images using YOLO task:**

# %% [markdown]
# Step 1: Synthetic dataset creation:

# %%
#importing necessary libraries
import cv2
import numpy as np
import os
import json
import random

# %%
# Parameters
num_images = 1000  # Number of images to generate
image_size = (256, 256)  # Size of the images
output_dir = 'circle_dataset'  # Directory to save the images and annotations
annotations = {}

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

# Function to create a random color
def random_color():
    return tuple(np.random.randint(0, 256, size=3).tolist())

# Function to generate random circles
def generate_random_circles(image):
    num_circles = np.random.randint(1, 4)  # Number of circles per image
    circles = []

    for _ in range(num_circles):
        center = tuple(np.random.randint(50, 206, size=2).tolist())
        radius = np.random.randint(20, 50)
        color = random_color()
        thickness = -1  # Filled circle
        cv2.circle(image, center, radius, color, thickness)
        circles.append({'center': center, 'radius': radius})

    return circles

# Function to generate negative examples (no circles)
def generate_negative_example(image):
    shape_type = np.random.choice(['square', 'triangle'])
    color = random_color()
    thickness = -1  # Filled shapes

    if shape_type == 'square':
        top_left = tuple(np.random.randint(50, 156, size=2).tolist())
        side_length = np.random.randint(50, 100)
        bottom_right = (top_left[0] + side_length, top_left[1] + side_length)
        cv2.rectangle(image, top_left, bottom_right, color, thickness)

    elif shape_type == 'triangle':
        pt1 = tuple(np.random.randint(50, 206, size=2).tolist())
        pt2 = tuple(np.random.randint(50, 206, size=2).tolist())
        pt3 = tuple(np.random.randint(50, 206, size=2).tolist())
        pts = np.array([pt1, pt2, pt3], np.int32)
        pts = pts.reshape((-1, 1, 2))
        cv2.fillPoly(image, [pts], color)

# Function to apply augmentations to enhance dataset
def apply_augmentations(image):
    # Random Flip
    flip_code = np.random.choice([-1, 0, 1])  # -1: horizontal and vertical, 0: vertical, 1: horizontal
    image = cv2.flip(image, flip_code)

    # Slight Rotation
    angle = np.random.randint(-15, 15)  # Rotation between -15 and 15 degrees
    M = cv2.getRotationMatrix2D((image_size[0] // 2, image_size[1] // 2), angle, 1)
    image = cv2.warpAffine(image, M, image_size)

    return image

# Generate and save images with annotations
for i in range(num_images):
    img = np.zeros((image_size[0], image_size[1], 3), dtype='uint8') + 255  # White background

    # 80% images with circles, 20% without
    if random.random() > 0.2:
        circles = generate_random_circles(img)
        annotations[f'image_{i:04d}.png'] = [{'center': c['center'], 'radius': c['radius']} for c in circles]
    else:
        generate_negative_example(img)
        annotations[f'image_{i:04d}.png'] = []

    img = apply_augmentations(img)

    # Save the image
    file_name = f'image_{i:04d}.png'
    file_path = os.path.join(output_dir, file_name)
    cv2.imwrite(file_path, img)

# Save annotations to a JSON file
with open(os.path.join(output_dir, 'annotations.json'), 'w') as f:
    json.dump(annotations, f, indent=4)

print(f'{num_images} images and annotations generated and saved in {output_dir}')
# Out:
# 1000 images and annotations generated and saved in circle_dataset

# %% [markdown]
# Step 2: preparing the data: convert annotations to YOLO format

# %%
import os

def convert_annotation(center, radius, img_size):
    x_center = center[0] / img_size[0]
    y_center = center[1] / img_size[1]
    width = height = 2 * radius / img_size[0]
    return f'0 {x_center} {y_center} {width} {height}'

# Convert annotations to YOLO format
labels_dir = os.path.join(output_dir, 'labels')
os.makedirs(labels_dir, exist_ok=True)

for img_name, circles in annotations.items():
    label_file = os.path.join(labels_dir, img_name.replace('.png', '.txt'))
    with open(label_file, 'w') as f:
        for circle in circles:
            yolo_annotation = convert_annotation(circle['center'], circle['radius'], image_size)
            f.write(yolo_annotation + '\n')

print(f'Annotations converted and saved in {labels_dir}')
# Out:
# Annotations converted and saved in circle_dataset/labels

# %% [markdown]
# Step 3: Modeling the dataset:
#
# > Add blockquote

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
from pathlib import Path

# Define paths
source_dir = 'circle_dataset'
train_image_dir = 'circle_dataset/images/train'
val_image_dir = 'circle_dataset/images/val'
test_image_dir = 'circle_dataset/images/test'

train_label_dir = 'circle_dataset/labels/train'
val_label_dir = 'circle_dataset/labels/val'
test_label_dir = 'circle_dataset/labels/test'

# Create directories if they don't exist
Path(train_image_dir).mkdir(parents=True, exist_ok=True)
Path(val_image_dir).mkdir(parents=True, exist_ok=True)
Path(test_image_dir).mkdir(parents=True, exist_ok=True)
Path(train_label_dir).mkdir(parents=True, exist_ok=True)
Path(val_label_dir).mkdir(parents=True, exist_ok=True)
Path(test_label_dir).mkdir(parents=True, exist_ok=True)

# Load annotations
with open(os.path.join(source_dir, 'annotations.json'), 'r') as f:
    annotations = json.load(f)

# Extract image file names
image_files = list(annotations.keys())

# Split dataset
train_images, val_images = train_test_split(image_files, test_size=0.3, random_state=42)
val_images, test_images = train_test_split(val_images, test_size=0.33, random_state=42)

def move_files(file_list, image_dest_dir, label_dest_dir):
    for file in file_list:
        # Move images
        img_src_path = os.path.join(source_dir, file)
        img_dest_path = os.path.join(image_dest_dir, file)
        shutil.move(img_src_path, img_dest_path)

        # Move corresponding labels
        label_file = file.replace('.png', '.txt')
        label_src_path = os.path.join(source_dir, 'labels', label_file)
        label_dest_path = os.path.join(label_dest_dir, label_file)
        shutil.move(label_src_path, label_dest_path)

# Move files
move_files(train_images, train_image_dir, train_label_dir)
move_files(val_images, val_image_dir, val_label_dir)
move_files(test_images, test_image_dir, test_label_dir)

print(f"Training images: {len(train_images)}")
print(f"Validation images: {len(val_images)}")
print(f"Test images: {len(test_images)}")
# Out:
# Training images: 700
# Validation images: 201
# Test images: 99

# %%
# Install Required Libraries
# !pip install torch torchvision tqdm

# Clone the YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5

# Change directory to yolov5 and install the required dependencies
# !pip install -r yolov5/requirements.txt
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.18.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.6.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# Requirement already satisfied: gitpython>=3.1.30 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 6)) (3.7.1)
# Requirement already satisfied: numpy>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 13)) (1.13.1)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 15)) (2.3.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 16)) (0.18.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 17)) (4.66.5)
# Requirement already satisfied: ultralytics>=8.2.34 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 18)) (8.2.76)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 27)) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 28)) (0.13.1)
# Requirement already satisfied: setuptools>=70.0.0 in /usr/local/lib/python3.10/dist-packages (from -r yolov5/requirements.txt (line 42)) (71.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.0->-r yolov5/requirements.txt (line 12)) (2024.7.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (12.6.20)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics>=8.2.34->-r yolov5/requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->-r yolov5/requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r yolov5/requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r yolov5/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->-r yolov5/requirements.txt (line 15)) (1.3.0)

# %%
import os
import shutil
from sklearn.model_selection import train_test_split
from pathlib import Path

# Define paths
source_dir = 'circle_dataset'
train_image_dir = 'circle_dataset/images/train'
val_image_dir = 'circle_dataset/images/val'
test_image_dir = 'circle_dataset/images/test'

train_label_dir = 'circle_dataset/labels/train'
val_label_dir = 'circle_dataset/labels/val'
test_label_dir = 'circle_dataset/labels/test'

# Create directories if they don't exist
Path(train_image_dir).mkdir(parents=True, exist_ok=True)
Path(val_image_dir).mkdir(parents=True, exist_ok=True)
Path(test_image_dir).mkdir(parents=True, exist_ok=True)
Path(train_label_dir).mkdir(parents=True, exist_ok=True)
Path(val_label_dir).mkdir(parents=True, exist_ok=True)
Path(test_label_dir).mkdir(parents=True, exist_ok=True)

# Load annotations
with open(os.path.join(source_dir, 'annotations.json'), 'r') as f:
    annotations = json.load(f)

# Extract image file names
image_files = list(annotations.keys())

# Split dataset
train_images, val_images = train_test_split(image_files, test_size=0.3, random_state=42)
val_images, test_images = train_test_split(val_images, test_size=0.33, random_state=42)

def move_files(file_list, image_dest_dir, label_dest_dir):
    for file in file_list:
        # Move images
        img_src_path = os.path.join(source_dir, file)
        img_dest_path = os.path.join(image_dest_dir, file)
        if os.path.exists(img_src_path):  # Check if the file exists
            shutil.move(img_src_path, img_dest_path)

        # Move corresponding labels
        label_file = file.replace('.png', '.txt')
        label_src_path = os.path.join(source_dir, 'labels', label_file)
        label_dest_path = os.path.join(label_dest_dir, label_file)
        if os.path.exists(label_src_path):  # Check if the file exists
            shutil.move(label_src_path, label_dest_path)

# Move files
move_files(train_images, train_image_dir, train_label_dir)
move_files(val_images, val_image_dir, val_label_dir)
move_files(test_images, test_image_dir, test_label_dir)

print(f"Training images: {len(train_images)}")
print(f"Validation images: {len(val_images)}")
print(f"Test images: {len(test_images)}")
#!rm -r circle_dataset (to remove and re create the entire dataset)
# Out:
# Training images: 700
# Validation images: 201
# Test images: 99

# %% [markdown]
# Step 4: Create a Dataset Configuration File

# %%
""" In the directory of yolov5/data:

or make sure you are in thr data directory and run the following commands:

# %%writefile circle_dataset.yaml

# circle_dataset.yaml

path: ../circle_dataset  # Path to the dataset root directory
train: images/train      # Path to training images
val: images/val          # Path to validation images

nc: 1                    # Number of classes (only one class: circle)
names: ['circle']        # Class name"""
# Out:
# Writing circle_dataset.yaml

# %% [markdown]
# Step 5: Train the YOLOv5 Model

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 256 --batch 16 --epochs 50 --data data/circle_dataset.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt --name circle_detection
# Out:
# 2024-08-12 22:50:24.567866: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08
/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:24<00:00,  3.55s/it]
#                    all        201        299      0.167      0.344      0.125     0.0371
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/49         0G     0.0603    0.02594          0         29        256: 100% 44/44 [03:18<00:00,  4.52s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:23<00:00,  3.36s/it]
#                    all        201        299      0.147      0.358      0.119     0.0359
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/49         0G    0.05998      0.027          0         40        256: 100% 44/44 [03:17<00:00,  4.50s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:23<00:00,  3.29s/it]
#                    all        201        299      0.147      0.361      0.118     0.0367
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/49         0G    0.06011    0.02583          0         30        256: 100% 44/44 [03:20<00:00,  4.55s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:26<00:00,  3.81s/it]
#                    all        201        299      0.154      0.344      0.117     0.0367
#
# 50 epochs completed in 3.129 hours.
# Optimizer stripped from runs/train/circle_detection/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/circle_detection/weights/best.pt, 14.3MB
#
# Validating runs/train/circle_detection/weights/best.pt...
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:24<00:00,  3.50s/it]
#                    all        201        299      0.149      0.308       0.12     0.0378
# Results saved to runs/train/circle_detection

# %% [markdown]
# Step **6**: Evaluate the Model

# %%
# !python val.py --data data/circle_dataset.yaml --weights runs/train/circle_detection/weights/best.pt --img 256
# Out:
# detect: weights=['runs/train/circle_detection/weights/best.pt'], source=../circle_dataset/images/val, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-351-g19ce9029 Python-3.10.12 torch-2.3.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/201 /content/circle_dataset/images/val/image_0002.png: 256x256 1 circle, 89.1ms
# image 2/201 /content/circle_dataset/images/val/image_0003.png: 256x256 (no detections), 70.3ms
# image 3/201 /content/circle_dataset/images/val/image_0005.png: 256x256 (no detections), 72.9ms
# image 4/201 /content/circle_dataset/images/val/image_0007.png: 256x256 (no detections), 77.6ms
# image 5/201 /content/circle_dataset/images/val/image_0009.png: 256x256 (no detections), 71.5ms
# image 6/201 /content/circle_dataset/images/val/image_0023.png: 256x256 (no detections), 70.9ms
# image 7/201 /content/circle_dataset/images/val/image_0025.png: 256x256 (no detections), 88.3ms
# image 8/201 /content/circle_dataset/images/val/image_0029.png: 256x256 (no detections), 70.3ms
# image 9/201 /content/circle_dataset/images/val/image_0030.png: 256x256 (no detections), 85.5ms
# image 10/201 /content/circle_dataset/images/val/image_0031.png: 256x256 (no detections), 69.5ms
# image 11/201 /content/circle_dataset/images/val/image_0044.png: 256x256 (no detections), 70.2ms
# image 12/201 /content/circle_dataset/images/val/image_0049.png: 256x256 (no detections), 73.6ms
# image 13/201 /content/circle_dataset/images/val/image_0054.png: 256x256 (no detections), 69.5ms
# image 14/201 /content/circle_dataset/images/val/image_0055.png: 256x256 (no detections), 70.6ms
# image 15/201 /content/circle_dataset/images/val/image_0059.png: 256x256 (no detections), 71.9ms
# image 16/201 /content/circle_dataset/images/val/image_0060.png: 256x256 (no detections), 77.6ms
# image 17/201 /content/circle_dataset/images/val/image_0063.png: 256x256 (no detections), 73.5ms
# image 18/201 /content/circle_dataset/images/val/image_0065.png: 256x256 (no detections), 70.5ms
# image 19/201 /content/circle_dataset/images/val/image_0066.png: 256x256 (no detections), 72.2ms
# image 20/201 /content/circle_dataset/images/val/image_0067.png: 256x256 (no detections), 78.9ms
# image 21/201 /content/circle_dataset/images/val/image_0072.png: 256x256 (no detections), 82.1ms
# image 22/201 /content/circle_dataset/images/val/image_0076.png: 256x256 (no detections), 80.1ms
# image 23/201 /content/circle_dataset/images/val/image_0077.png: 256x256 (no detections), 71.1ms
# image 24/201 /content/circle_dataset/images/val/image_0078.png: 256x256 (no detections), 72.4ms
# image 25/201 /content/circle_dataset/images/val/image_0084.png: 256x256 (no detections), 71.9ms
# image 26/201 /content/circle_dataset/images/val/image_0096.png: 256x256 (no detections), 73.2ms
# image 27/201 /content/circle_dataset/images/val/image_0097.png: 256x256 (no detections), 75.6ms
# image 28/201 /content/circle_dataset/images/val/image_0101.png: 256x256 (no detections), 72.0ms
# image 29/201 /content/circle_dataset/images/val/image_0107.png: 256x256 (no detections), 73.3ms
# image 30/201 /content/circle_dataset/images/val/image_0109.png: 256x256 (no detections), 73.5ms
# image 31/201 /content/circle_dataset/images/val/image_0110.png: 256x256 (no detections), 71.8ms
# image 32/201 /content/circle_dataset/images/val/image_0118.png: 256x256 (no detections), 72.1ms
# image 33/201 /content/circle_dataset/images/val/image_0120.png: 256x256 (no detections), 80.9ms
# image 34/201 /content/circle_dataset/images/val/image_0139.png: 256x256 (no detections), 87.7ms
# image 35/201 /content/circle_dataset/images/val/image_0155.png: 256x256 (no detections), 77.2ms
# image 36/201 /content/circle_dataset/images/val/image_0158.png: 256x256 (no detections), 71.4ms
# image 37/201 /content/circle_dataset/images/val/image_0165.png: 256x256 (no detections), 71.9ms
# image 38/201 /content/circle_dataset/images/val/image_0174.png: 256x256 (no detections), 79.0ms
# image 39/201 /content/circle_dataset/images/val/image_0184.png: 256x256 (no detections), 71.1ms
# image 40/201 /content/circle_dataset/images/val/image_0196.png: 256x256 (no detections), 77.6ms
# image 41/201 /content/circle_dataset/images/val/image_0198.png: 256x256 (no detections), 72.0ms
# image 42/201 /content/circle_dataset/images/val/image_0204.png: 256x256 (no detections), 74.6ms
# image 43/201 /content/circle_dataset/images/val/image_0208.png: 256x256 (no detections), 72.0ms
# image 44/201 /content/circle_dataset/images/val/image_0211.png: 256x256 (no detections), 75.5ms
# image 45/201 /content/circle_dataset/images/val/image_0215.png: 256x256 (no detections), 71.9ms
# image 46/201 /content/circle_dataset/images/val/image_0221.png: 256x256 (no detections), 73.2ms
# image 47/201 /content/circle_dataset/images/val/image_0231.png: 256x256 (no detections), 128.0ms
# image 48/201 /content/circle_dataset/images/val/image_0247.png: 256x256 (no detections), 70.9ms
# image 49/201 /content/circle_dataset/images/val/image_0249.png: 256x256 (no detections), 77.3ms
# image 50/201 /content/circle_dataset/images/val/image_0250.png: 256x256 (no detections), 71.7ms
# image 51/201 /content/circle_dataset/images/val/image_0254.png: 256x256 (no detections), 70.9ms
# image 52/201 /content/circle_dataset/images/val/image_0256.png: 256x256 (no detections), 71.6ms
# image 53/201 /content/circle_dataset/images/val/image_0259.png: 256x256 (no detections), 76.0ms
# image 54/201 /content/circle_dataset/images/val/image_0260.png: 256x256 (no detections), 73.1ms
# image 55/201 /content/circle_dataset/images/val/image_0261.png: 256x256 (no detections), 75.1ms
# image 56/201 /content/circle_dataset/images/val/image_0265.png: 256x256 (no detections), 71.2ms
# image 57/201 /content/circle_dataset/images/val/image_0266.png: 256x256 (no detections), 74.6ms
# image 58/201 /content/circle_dataset/images/val/image_0281.png: 256x256 (no detections), 74.6ms
# image 59/201 /content/circle_dataset/images/val/image_0290.png: 256x256 (no detections), 71.8ms
# image 60/201 /content/circle_dataset/images/val/image_0292.png: 256x256 (no detections), 92.1ms
# image 61/201 /content/circle_dataset/images/val/image_0298.png: 256x256 (no detections), 68.8ms
# image 62/201 /content/circle_dataset/images/val/image_0299.png: 256x256 (no detections), 71.5ms
# image 63/201 /content/circle_dataset/images/val/image_0305.png: 256x256 (no detections), 71.0ms
# image 64/201 /content/circle_dataset/images/val/image_0306.png: 256x256 (no detections), 72.5ms
# image 65/201 /content/circle_dataset/images/val/image_0309.png: 256x256 (no detections), 71.1ms
# image 66/201 /content/circle_dataset/images/val/image_0310.png: 256x256 (no detections), 74.2ms
# image 67/201 /content/circle_dataset/images/val/image_0314.png: 256x256 (no detections), 72.4ms
# image 68/201 /content/circle_dataset/images/val/image_0321.png: 256x256 (no detections), 72.1ms
# image 69/201 /content/circle_dataset/images/val/image_0323.png: 256x256 (no detections), 70.4ms
# image 70/201 /content/circle_dataset/images/val/image_0327.png: 256x256 (no detections), 72.6ms
# image 71/201 /content/circle_dataset/images/val/image_0328.png: 256x256 (no detections), 73.8ms
# image 72/201 /content/circle_dataset/images/val/image_0350.png: 256x256 (no detections), 78.0ms
# image 73/201 /content/circle_dataset/images/val/image_0357.png: 256x256 (no detections), 96.4ms
# image 74/201 /content/circle_dataset/images/val/image_0361.png: 256x256 (no detections), 71.7ms
# image 75/201 /content/circle_dataset/images/val/image_0362.png: 256x256 (no detections), 71.0ms
# image 76/201 /content/circle_dataset/images/val/image_0365.png: 256x256 (no detections), 74.4ms
# image 77/201 /content/circle_dataset/images/val/image_0370.png: 256x256 (no detections), 78.6ms
# image 78/201 /content/circle_dataset/images/val/image_0380.png: 256x256 (no detections), 74.6ms
# image 79/201 /content/circle_dataset/images/val/image_0381.png: 256x256 (no detections), 71.2ms
# image 80/201 /content/circle_dataset/images/val/image_0398.png: 256x256 (no detections), 78.0ms
# image 81/201 /content/circle_dataset/images/val/image_0408.png: 256x256 (no detections), 71.6ms
# image 82/201 /content/circle_dataset/images/val/image_0411.png: 256x256 (no detections), 73.1ms
# image 83/201 /content/circle_dataset/images/val/image_0425.png: 256x256 (no detections), 71.3ms
# image 84/201 /content/circle_dataset/images/val/image_0429.png: 256x256 (no detections), 76.0ms
# image 85/201 /content/circle_dataset/images/val/image_0430.png: 256x256 (no detections), 73.4ms
# image 153/201 /content/circle_dataset/images/val/image_0783.png: 256x256 (no detections), 80.1ms
# image 154/201 /content/circle_dataset/images/val/image_0787.png: 256x256 (no detections), 70.1ms
# image 155/201 /content/circle_dataset/images/val/image_0789.png: 256x256 (no detections), 70.5ms
# image 156/201 /content/circle_dataset/images/val/image_0796.png: 256x256 (no detections), 72.1ms
# image 157/201 /content/circle_dataset/images/val/image_0799.png: 256x256 (no detections), 72.7ms
# image 158/201 /content/circle_dataset/images/val/image_0802.png: 256x256 (no detections), 84.8ms
# image 159/201 /content/circle_dataset/images/val/image_0810.png: 256x256 (no detections), 71.8ms
# image 160/201 /content/circle_dataset/images/val/image_0824.png: 256x256 (no detections), 70.0ms
# image 161/201 /content/circle_dataset/images/val/image_0826.png: 256x256 (no detections), 75.7ms
# image 162/201 /content/circle_dataset/images/val/image_0827.png: 256x256 (no detections), 71.0ms
# image 163/201 /content/circle_dataset/images/val/image_0829.png: 256x256 (no detections), 72.7ms
# image 164/201 /content/circle_dataset/images/val/image_0836.png: 256x256 (no detections), 71.8ms
# image 165/201 /content/circle_dataset/images/val/image_0837.png: 256x256 (no detections), 79.8ms
# image 166/201 /content/circle_dataset/images/val/image_0845.png: 256x256 (no detections), 79.1ms
# image 167/201 /content/circle_dataset/images/val/image_0849.png: 256x256 (no detections), 76.4ms
# image 168/201 /content/circle_dataset/images/val/image_0859.png: 256x256 (no detections), 70.3ms
# image 169/201 /content/circle_dataset/images/val/image_0866.png: 256x256 (no detections), 73.0ms
# image 170/201 /content/circle_dataset/images/val/image_0867.png: 256x256 (no detections), 73.5ms
# image 171/201 /content/circle_dataset/images/val/image_0868.png: 256x256 (no detections), 72.1ms
# image 172/201 /content/circle_dataset/images/val/image_0879.png: 256x256 (no detections), 84.2ms
# image 173/201 /content/circle_dataset/images/val/image_0884.png: 256x256 (no detections), 69.5ms
# image 174/201 /content/circle_dataset/images/val/image_0892.png: 256x256 (no detections), 72.4ms
# image 175/201 /content/circle_dataset/images/val/image_0894.png: 256x256 (no detections), 70.9ms
# image 176/201 /content/circle_dataset/images/val/image_0900.png: 256x256 (no detections), 75.4ms
# image 177/201 /content/circle_dataset/images/val/image_0901.png: 256x256 (no detections), 71.4ms
# image 178/201 /content/circle_dataset/images/val/image_0902.png: 256x256 (no detections), 71.2ms
# image 179/201 /content/circle_dataset/images/val/image_0904.png: 256x256 (no detections), 79.1ms
# image 180/201 /content/circle_dataset/images/val/image_0914.png: 256x256 (no detections), 71.8ms
# image 181/201 /content/circle_dataset/images/val/image_0916.png: 256x256 (no detections), 70.1ms
# image 182/201 /content/circle_dataset/images/val/image_0918.png: 256x256 (no detections), 76.4ms
# image 183/201 /content/circle_dataset/images/val/image_0922.png: 256x256 (no detections), 71.1ms
# image 184/201 /content/circle_dataset/images/val/image_0925.png: 256x256 (no detections), 74.4ms
# image 185/201 /content/circle_dataset/images/val/image_0935.png: 256x256 (no detections), 83.4ms
# image 186/201 /content/circle_dataset/images/val/image_0936.png: 256x256 (no detections), 70.1ms
# image 187/201 /content/circle_dataset/images/val/image_0938.png: 256x256 (no detections), 71.8ms
# image 188/201 /content/circle_dataset/images/val/image_0942.png: 256x256 (no detections), 78.2ms
# image 189/201 /content/circle_dataset/images/val/image_0946.png: 256x256 (no detections), 73.0ms
# image 190/201 /content/circle_dataset/images/val/image_0947.png: 256x256 (no detections), 70.7ms
# image 191/201 /content/circle_dataset/images/val/image_0948.png: 256x256 (no detections), 73.3ms
# image 192/201 /content/circle_dataset/images/val/image_0959.png: 256x256 (no detections), 80.8ms
# image 193/201 /content/circle_dataset/images/val/image_0973.png: 256x256 (no detections), 74.3ms
# image 194/201 /content/circle_dataset/images/val/image_0974.png: 256x256 (no detections), 71.0ms
# image 195/201 /content/circle_dataset/images/val/image_0975.png: 256x256 (no detections), 71.8ms
# image 196/201 /content/circle_dataset/images/val/image_0978.png: 256x256 (no detections), 74.9ms
# image 197/201 /content/circle_dataset/images/val/image_0985.png: 256x256 (no detections), 71.6ms
# image 198/201 /content/circle_dataset/images/val/image_0986.png: 256x256 1 circle, 82.3ms
# image 199/201 /content/circle_dataset/images/val/image_0991.png: 256x256 (no detections), 73.4ms
# image 200/201 /content/circle_dataset/images/val/image_0995.png: 256x256 (no detections), 74.3ms
# image 201/201 /content/circle_dataset/images/val/image_0998.png: 256x256 (no detections), 72.7ms
# Speed: 0.3ms pre-process, 83.0ms inference, 0.2ms NMS per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/exp

# %% [markdown]
# Step 7: Visualize the Detection Results

# %%
# !python detect.py --weights runs/train/circle_detection/weights/best.pt --img 256 --conf 0.5 --source ../circle_dataset/images/val
# Out:
# detect: weights=['runs/train/circle_detection/weights/best.pt'], source=../circle_dataset/images/val, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-351-g19ce9029 Python-3.10.12 torch-2.3.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/201 /content/circle_dataset/images/val/image_0002.png: 256x256 (no detections), 82.9ms
# image 2/201 /content/circle_dataset/images/val/image_0003.png: 256x256 (no detections), 72.6ms
# image 3/201 /content/circle_dataset/images/val/image_0005.png: 256x256 (no detections), 70.9ms
# image 4/201 /content/circle_dataset/images/val/image_0007.png: 256x256 (no detections), 69.2ms
# image 5/201 /content/circle_dataset/images/val/image_0009.png: 256x256 (no detections), 72.9ms
# image 6/201 /content/circle_dataset/images/val/image_0023.png: 256x256 (no detections), 75.2ms
# image 7/201 /content/circle_dataset/images/val/image_0025.png: 256x256 (no detections), 71.6ms
# image 8/201 /content/circle_dataset/images/val/image_0029.png: 256x256 (no detections), 74.6ms
# image 9/201 /content/circle_dataset/images/val/image_0030.png: 256x256 (no detections), 69.6ms
# image 10/201 /content/circle_dataset/images/val/image_0031.png: 256x256 (no detections), 70.5ms
# image 11/201 /content/circle_dataset/images/val/image_0044.png: 256x256 (no detections), 78.8ms
# image 12/201 /content/circle_dataset/images/val/image_0049.png: 256x256 (no detections), 80.2ms
# image 13/201 /content/circle_dataset/images/val/image_0054.png: 256x256 (no detections), 71.0ms
# image 14/201 /content/circle_dataset/images/val/image_0055.png: 256x256 (no detections), 71.4ms
# image 15/201 /content/circle_dataset/images/val/image_0059.png: 256x256 (no detections), 75.2ms
# image 16/201 /content/circle_dataset/images/val/image_0060.png: 256x256 (no detections), 112.6ms
# image 17/201 /content/circle_dataset/images/val/image_0063.png: 256x256 (no detections), 121.8ms
# image 18/201 /content/circle_dataset/images/val/image_0065.png: 256x256 (no detections), 117.4ms
# image 19/201 /content/circle_dataset/images/val/image_0066.png: 256x256 (no detections), 114.6ms
# image 20/201 /content/circle_dataset/images/val/image_0067.png: 256x256 (no detections), 112.0ms
# image 21/201 /content/circle_dataset/images/val/image_0072.png: 256x256 (no detections), 119.5ms
# image 22/201 /content/circle_dataset/images/val/image_0076.png: 256x256 (no detections), 111.9ms
# image 23/201 /content/circle_dataset/images/val/image_0077.png: 256x256 (no detections), 112.5ms
# image 24/201 /content/circle_dataset/images/val/image_0078.png: 256x256 (no detections), 119.8ms
# image 25/201 /content/circle_dataset/images/val/image_0084.png: 256x256 (no detections), 112.4ms
# image 26/201 /content/circle_dataset/images/val/image_0096.png: 256x256 (no detections), 110.7ms
# image 27/201 /content/circle_dataset/images/val/image_0097.png: 256x256 (no detections), 109.0ms
# image 28/201 /content/circle_dataset/images/val/image_0101.png: 256x256 (no detections), 109.2ms
# image 29/201 /content/circle_dataset/images/val/image_0107.png: 256x256 (no detections), 120.6ms
# image 30/201 /content/circle_dataset/images/val/image_0109.png: 256x256 (no detections), 117.3ms
# image 31/201 /content/circle_dataset/images/val/image_0110.png: 256x256 (no detections), 115.3ms
# image 32/201 /content/circle_dataset/images/val/image_0118.png: 256x256 (no detections), 115.8ms
# image 33/201 /content/circle_dataset/images/val/image_0120.png: 256x256 (no detections), 108.6ms
# image 34/201 /content/circle_dataset/images/val/image_0139.png: 256x256 (no detections), 115.1ms
# image 35/201 /content/circle_dataset/images/val/image_0155.png: 256x256 (no detections), 113.3ms
# image 36/201 /content/circle_dataset/images/val/image_0158.png: 256x256 (no detections), 112.9ms
# image 37/201 /content/circle_dataset/images/val/image_0165.png: 256x256 (no detections), 119.0ms
# image 38/201 /content/circle_dataset/images/val/image_0174.png: 256x256 (no detections), 117.7ms
# image 39/201 /content/circle_dataset/images/val/image_0184.png: 256x256 (no detections), 124.4ms
# image 40/201 /content/circle_dataset/images/val/image_0196.png: 256x256 (no detections), 117.7ms
# image 41/201 /content/circle_dataset/images/val/image_0198.png: 256x256 (no detections), 117.5ms
# image 42/201 /content/circle_dataset/images/val/image_0204.png: 256x256 (no detections), 118.4ms
# image 43/201 /content/circle_dataset/images/val/image_0208.png: 256x256 (no detections), 121.6ms
# image 44/201 /content/circle_dataset/images/val/image_0211.png: 256x256 (no detections), 117.1ms
# image 45/201 /content/circle_dataset/images/val/image_0215.png: 256x256 (no detections), 117.6ms
# image 46/201 /content/circle_dataset/images/val/image_0221.png: 256x256 (no detections), 122.6ms
# image 47/201 /content/circle_dataset/images/val/image_0231.png: 256x256 (no detections), 114.9ms
# image 48/201 /content/circle_dataset/images/val/image_0247.png: 256x256 (no detections), 141.9ms
# image 49/201 /content/circle_dataset/images/val/image_0249.png: 256x256 (no detections), 116.4ms
# image 50/201 /content/circle_dataset/images/val/image_0250.png: 256x256 (no detections), 124.1ms
# image 51/201 /content/circle_dataset/images/val/image_0254.png: 256x256 (no detections), 122.7ms
# image 52/201 /content/circle_dataset/images/val/image_0256.png: 256x256 (no detections), 119.7ms
# image 53/201 /content/circle_dataset/images/val/image_0259.png: 256x256 (no detections), 125.7ms
# image 54/201 /content/circle_dataset/images/val/image_0260.png: 256x256 (no detections), 111.1ms
# image 55/201 /content/circle_dataset/images/val/image_0261.png: 256x256 (no detections), 118.2ms
# image 56/201 /content/circle_dataset/images/val/image_0265.png: 256x256 (no detections), 129.2ms
# image 57/201 /content/circle_dataset/images/val/image_0266.png: 256x256 (no detections), 80.7ms
# image 58/201 /content/circle_dataset/images/val/image_0281.png: 256x256 (no detections), 74.2ms
# image 59/201 /content/circle_dataset/images/val/image_0290.png: 256x256 (no detections), 75.1ms
# image 60/201 /content/circle_dataset/images/val/image_0292.png: 256x256 (no detections), 73.9ms
# image 61/201 /content/circle_dataset/images/val/image_0298.png: 256x256 (no detections), 71.3ms
# image 62/201 /content/circle_dataset/images/val/image_0299.png: 256x256 (no detections), 70.4ms
# image 63/201 /content/circle_dataset/images/val/image_0305.png: 256x256 (no detections), 74.3ms
# image 64/201 /content/circle_dataset/images/val/image_0306.png: 256x256 (no detections), 81.2ms
# image 65/201 /content/circle_dataset/images/val/image_0309.png: 256x256 (no detections), 70.5ms
# image 66/201 /content/circle_dataset/images/val/image_0310.png: 256x256 (no detections), 70.1ms
# image 67/201 /content/circle_dataset/images/val/image_0314.png: 256x256 (no detections), 70.6ms
# image 68/201 /content/circle_dataset/images/val/image_0321.png: 256x256 (no detections), 71.5ms
# image 69/201 /content/circle_dataset/images/val/image_0323.png: 256x256 (no detections), 77.7ms
# image 70/201 /content/circle_dataset/images/val/image_0327.png: 256x256 (no detections), 81.2ms
# image 71/201 /content/circle_dataset/images/val/image_0328.png: 256x256 (no detections), 70.3ms
# image 72/201 /content/circle_dataset/images/val/image_0350.png: 256x256 (no detections), 72.1ms
# image 73/201 /content/circle_dataset/images/val/image_0357.png: 256x256 (no detections), 72.2ms
# image 74/201 /content/circle_dataset/images/val/image_0361.png: 256x256 (no detections), 73.1ms
# image 75/201 /content/circle_dataset/images/val/image_0362.png: 256x256 (no detections), 70.3ms
# image 76/201 /content/circle_dataset/images/val/image_0365.png: 256x256 (no detections), 75.9ms
# image 77/201 /content/circle_dataset/images/val/image_0370.png: 256x256 (no detections), 77.7ms
# image 78/201 /content/circle_dataset/images/val/image_0380.png: 256x256 (no detections), 71.2ms
# image 79/201 /content/circle_dataset/images/val/image_0381.png: 256x256 (no detections), 71.4ms
# image 80/201 /content/circle_dataset/images/val/image_0398.png: 256x256 (no detections), 70.4ms
# image 81/201 /content/circle_dataset/images/val/image_0408.png: 256x256 (no detections), 70.2ms
# image 82/201 /content/circle_dataset/images/val/image_0411.png: 256x256 (no detections), 76.3ms
# image 83/201 /content/circle_dataset/images/val/image_0425.png: 256x256 (no detections), 86.0ms
# image 84/201 /content/circle_dataset/images/val/image_0429.png: 256x256 (no detections), 71.0ms
# image 85/201 /content/circle_dataset/images/val/image_0430.png: 256x256 (no detections), 71.4ms
# image 86/201 /content/circle_dataset/images/val/image_0432.png: 256x256 (no detections), 74.1ms
# image 87/201 /content/circle_dataset/images/val/image_0436.png: 256x256 (no detections), 72.6ms
# image 88/201 /content/circle_dataset/images/val/image_0439.png: 256x256 (no detections), 79.4ms
# image 89/201 /content/circle_dataset/images/val/image_0445.png: 256x256 (no detections), 74.6ms
# image 90/201 /content/circle_dataset/images/val/image_0449.png: 256x256 (no detections), 83.3ms
# image 91/201 /content/circle_dataset/images/val/image_0451.png: 256x256 (no detections), 70.9ms
# image 92/201 /content/circle_dataset/images/val/image_0462.png: 256x256 (no detections), 70.2ms
# image 93/201 /content/circle_dataset/images/val/image_0464.png: 256x256 (no detections), 70.4ms
# image 94/201 /content/circle_dataset/images/val/image_0465.png: 256x256 (no detections), 73.3ms
# image 95/201 /content/circle_dataset/images/val/image_0479.png: 256x256 (no detections), 70.5ms
# image 96/201 /content/circle_dataset/images/val/image_0486.png: 256x256 (no detections), 85.8ms
# image 97/201 /content/circle_dataset/images/val/image_0490.png: 256x256 (no detections), 70.4ms
# image 98/201 /content/circle_dataset/images/val/image_0493.png: 256x256 (no detections), 74.2ms
# image 99/201 /content/circle_dataset/images/val/image_0495.png: 256x256 (no detections), 71.4ms
# image 100/201 /content/circle_dataset/images/val/image_0501.png: 256x256 (no detections), 71.6ms
# image 101/201 /content/circle_dataset/images/val/image_0514.png: 256x256 (no detections), 69.4ms
# image 102/201 /content/circle_dataset/images/val/image_0521.png: 256x256 (no detections), 80.7ms
# image 103/201 /content/circle_dataset/images/val/image_0526.png: 256x256 (no detections), 76.3ms
# image 104/201 /content/circle_dataset/images/val/image_0527.png: 256x256 (no detections), 69.6ms
# image 105/201 /content/circle_dataset/images/val/image_0528.png: 256x256 (no detections), 69.8ms
# image 106/201 /content/circle_dataset/images/val/image_0529.png: 256x256 (no detections), 72.3ms
# image 107/201 /content/circle_dataset/images/val/image_0535.png: 256x256 (no detections), 70.5ms
# image 108/201 /content/circle_dataset/images/val/image_0542.png: 256x256 (no detections), 73.9ms
# image 109/201 /content/circle_dataset/images/val/image_0543.png: 256x256 (no detections), 71.2ms
# image 110/201 /content/circle_dataset/images/val/image_0548.png: 256x256 (no detections), 83.3ms
# image 111/201 /content/circle_dataset/images/val/image_0549.png: 256x256 (no detections), 72.0ms
# image 112/201 /content/circle_dataset/images/val/image_0554.png: 256x256 (no detections), 72.4ms
# image 113/201 /content/circle_dataset/images/val/image_0559.png: 256x256 (no detections), 74.3ms
# image 114/201 /content/circle_dataset/images/val/image_0570.png: 256x256 (no detections), 69.9ms
# image 115/201 /content/circle_dataset/images/val/image_0578.png: 256x256 (no detections), 71.4ms
# image 116/201 /content/circle_dataset/images/val/image_0587.png: 256x256 (no detections), 75.7ms
# image 117/201 /content/circle_dataset/images/val/image_0595.png: 256x256 (no detections), 76.7ms
# image 118/201 /content/circle_dataset/images/val/image_0596.png: 256x256 (no detections), 69.4ms
# image 119/201 /content/circle_dataset/images/val/image_0599.png: 256x256 (no detections), 69.2ms
# image 120/201 /content/circle_dataset/images/val/image_0601.png: 256x256 (no detections), 70.3ms
# image 121/201 /content/circle_dataset/images/val/image_0603.png: 256x256 (no detections), 73.9ms
# image 122/201 /content/circle_dataset/images/val/image_0604.png: 256x256 (no detections), 70.1ms
# image 123/201 /content/circle_dataset/images/val/image_0613.png: 256x256 (no detections), 85.0ms
# image 124/201 /content/circle_dataset/images/val/image_0621.png: 256x256 (no detections), 73.3ms
# image 125/201 /content/circle_dataset/images/val/image_0631.png: 256x256 (no detections), 73.6ms
# image 126/201 /content/circle_dataset/images/val/image_0636.png: 256x256 (no detections), 71.5ms
# image 127/201 /content/circle_dataset/images/val/image_0643.png: 256x256 (no detections), 69.1ms
# image 128/201 /content/circle_dataset/images/val/image_0644.png: 256x256 (no detections), 70.3ms
# image 129/201 /content/circle_dataset/images/val/image_0649.png: 256x256 (no detections), 79.4ms
# image 130/201 /content/circle_dataset/images/val/image_0655.png: 256x256 (no detections), 71.6ms
# image 131/201 /content/circle_dataset/images/val/image_0660.png: 256x256 (no detections), 71.8ms
# image 132/201 /content/circle_dataset/images/val/image_0664.png: 256x256 (no detections), 74.6ms
# image 133/201 /content/circle_dataset/images/val/image_0670.png: 256x256 (no detections), 72.6ms
# image 134/201 /content/circle_dataset/images/val/image_0679.png: 256x256 (no detections), 70.2ms
# image 135/201 /content/circle_dataset/images/val/image_0687.png: 256x256 (no detections), 71.0ms
# image 136/201 /content/circle_dataset/images/val/image_0689.png: 256x256 (no detections), 73.9ms
# image 137/201 /content/circle_dataset/images/val/image_0692.png: 256x256 (no detections), 84.9ms
# image 138/201 /content/circle_dataset/images/val/image_0695.png: 256x256 (no detections), 73.1ms
# image 139/201 /content/circle_dataset/images/val/image_0708.png: 256x256 (no detections), 80.6ms
# image 140/201 /content/circle_dataset/images/val/image_0713.png: 256x256 (no detections), 107.1ms
# image 141/201 /content/circle_dataset/images/val/image_0714.png: 256x256 (no detections), 71.4ms
# image 142/201 /content/circle_dataset/images/val/image_0716.png: 256x256 (no detections), 80.1ms
# image 143/201 /content/circle_dataset/images/val/image_0717.png: 256x256 (no detections), 69.9ms
# image 144/201 /content/circle_dataset/images/val/image_0721.png: 256x256 (no detections), 76.7ms
# image 145/201 /content/circle_dataset/images/val/image_0731.png: 256x256 (no detections), 71.4ms
# image 146/201 /content/circle_dataset/images/val/image_0737.png: 256x256 (no detections), 71.4ms
# image 147/201 /content/circle_dataset/images/val/image_0740.png: 256x256 (no detections), 71.0ms
# image 148/201 /content/circle_dataset/images/val/image_0749.png: 256x256 (no detections), 73.4ms
# image 149/201 /content/circle_dataset/images/val/image_0753.png: 256x256 (no detections), 81.9ms
# image 150/201 /content/circle_dataset/images/val/image_0761.png: 256x256 (no detections), 74.8ms
# image 151/201 /content/circle_dataset/images/val/image_0764.png: 256x256 (no detections), 73.1ms
# image 152/201 /content/circle_dataset/images/val/image_0767.png: 256x256 (no detections), 72.9ms
# image 153/201 /content/circle_dataset/images/val/image_0783.png: 256x256 (no detections), 71.7ms
# image 154/201 /content/circle_dataset/images/val/image_0787.png: 256x256 (no detections), 72.8ms
# image 155/201 /content/circle_dataset/images/val/image_0789.png: 256x256 (no detections), 74.7ms
# image 156/201 /content/circle_dataset/images/val/image_0796.png: 256x256 (no detections), 72.9ms
# image 157/201 /content/circle_dataset/images/val/image_0799.png: 256x256 (no detections), 70.4ms
# image 158/201 /content/circle_dataset/images/val/image_0802.png: 256x256 (no detections), 70.6ms
# image 159/201 /content/circle_dataset/images/val/image_0810.png: 256x256 (no detections), 76.9ms
# image 160/201 /content/circle_dataset/images/val/image_0824.png: 256x256 (no detections), 78.0ms
# image 161/201 /content/circle_dataset/images/val/image_0826.png: 256x256 (no detections), 110.6ms
# image 162/201 /content/circle_dataset/images/val/image_0827.png: 256x256 (no detections), 89.2ms
# image 163/201 /content/circle_dataset/images/val/image_0829.png: 256x256 (no detections), 75.7ms
# image 164/201 /content/circle_dataset/images/val/image_0836.png: 256x256 (no detections), 71.8ms
# image 165/201 /content/circle_dataset/images/val/image_0837.png: 256x256 (no detections), 71.9ms
# image 166/201 /content/circle_dataset/images/val/image_0845.png: 256x256 (no detections), 74.7ms
# image 167/201 /content/circle_dataset/images/val/image_0849.png: 256x256 (no detections), 80.5ms
# image 168/201 /content/circle_dataset/images/val/image_0859.png: 256x256 (no detections), 71.6ms
# image 169/201 /content/circle_dataset/images/val/image_0866.png: 256x256 (no detections), 70.2ms
# image 170/201 /content/circle_dataset/images/val/image_0867.png: 256x256 (no detections), 72.0ms
# image 171/201 /content/circle_dataset/images/val/image_0868.png: 256x256 (no detections), 71.6ms
# image 172/201 /content/circle_dataset/images/val/image_0879.png: 256x256 (no detections), 77.5ms
# image 173/201 /content/circle_dataset/images/val/image_0884.png: 256x256 (no detections), 72.8ms
# image 174/201 /content/circle_dataset/images/val/image_0892.png: 256x256 (no detections), 71.6ms
# image 175/201 /content/circle_dataset/images/val/image_0894.png: 256x256 (no detections), 83.2ms
# image 176/201 /content/circle_dataset/images/val/image_0900.png: 256x256 (no detections), 75.5ms
# image 177/201 /content/circle_dataset/images/val/image_0901.png: 256x256 (no detections), 72.6ms
# image 178/201 /content/circle_dataset/images/val/image_0902.png: 256x256 (no detections), 72.3ms
# image 179/201 /content/circle_dataset/images/val/image_0904.png: 256x256 (no detections), 85.1ms
# image 180/201 /content/circle_dataset/images/val/image_0914.png: 256x256 (no detections), 72.6ms
# image 181/201 /content/circle_dataset/images/val/image_0916.png: 256x256 (no detections), 71.4ms
# image 182/201 /content/circle_dataset/images/val/image_0918.png: 256x256 (no detections), 69.3ms
# image 183/201 /content/circle_dataset/images/val/image_0922.png: 256x256 (no detections), 74.3ms
# image 184/201 /content/circle_dataset/images/val/image_0925.png: 256x256 (no detections), 70.9ms
# image 185/201 /content/circle_dataset/images/val/image_0935.png: 256x256 (no detections), 100.3ms
# image 186/201 /content/circle_dataset/images/val/image_0936.png: 256x256 (no detections), 119.4ms
# image 187/201 /content/circle_dataset/images/val/image_0938.png: 256x256 (no detections), 126.0ms
# image 188/201 /content/circle_dataset/images/val/image_0942.png: 256x256 (no detections), 116.2ms
# image 189/201 /content/circle_dataset/images/val/image_0946.png: 256x256 (no detections), 109.9ms
# image 190/201 /content/circle_dataset/images/val/image_0947.png: 256x256 (no detections), 109.3ms
# image 191/201 /content/circle_dataset/images/val/image_0948.png: 256x256 (no detections), 108.1ms
# image 192/201 /content/circle_dataset/images/val/image_0959.png: 256x256 (no detections), 108.9ms
# image 193/201 /content/circle_dataset/images/val/image_0973.png: 256x256 (no detections), 110.5ms
# image 194/201 /content/circle_dataset/images/val/image_0974.png: 256x256 (no detections), 117.8ms
# image 195/201 /content/circle_dataset/images/val/image_0975.png: 256x256 (no detections), 106.8ms
# image 196/201 /content/circle_dataset/images/val/image_0978.png: 256x256 (no detections), 119.7ms
# image 197/201 /content/circle_dataset/images/val/image_0985.png: 256x256 (no detections), 107.9ms
# image 198/201 /content/circle_dataset/images/val/image_0986.png: 256x256 (no detections), 107.7ms
# image 199/201 /content/circle_dataset/images/val/image_0991.png: 256x256 (no detections), 108.5ms
# image 200/201 /content/circle_dataset/images/val/image_0995.png: 256x256 (no detections), 116.8ms
# image 201/201 /content/circle_dataset/images/val/image_0998.png: 256x256 (no detections), 114.1ms
# Speed: 0.3ms pre-process, 86.4ms inference, 0.2ms NMS per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/exp6

# %% [markdown]
# Step  8: Testing the Model

# %%
# !python detect.py --weights runs/train/circle_detection/weights/best.pt --img 256 --conf 0.4 --source /content/circle_dataset/images/test --save-txt --save-conf
# Out:
# detect: weights=['runs/train/circle_detection/weights/best.pt'], source=/content/circle_dataset/images/test, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-351-g19ce9029 Python-3.10.12 torch-2.3.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/99 /content/circle_dataset/images/test/image_0010.png: 256x256 (no detections), 148.6ms
# image 2/99 /content/circle_dataset/images/test/image_0033.png: 256x256 (no detections), 132.0ms
# image 3/99 /content/circle_dataset/images/test/image_0039.png: 256x256 (no detections), 122.6ms
# image 4/99 /content/circle_dataset/images/test/image_0070.png: 256x256 (no detections), 131.5ms
# image 5/99 /content/circle_dataset/images/test/image_0081.png: 256x256 (no detections), 138.3ms
# image 6/99 /content/circle_dataset/images/test/image_0082.png: 256x256 (no detections), 122.9ms
# image 7/99 /content/circle_dataset/images/test/image_0086.png: 256x256 (no detections), 133.1ms
# image 8/99 /content/circle_dataset/images/test/image_0088.png: 256x256 (no detections), 129.5ms
# image 9/99 /content/circle_dataset/images/test/image_0136.png: 256x256 (no detections), 136.0ms
# image 10/99 /content/circle_dataset/images/test/image_0137.png: 256x256 (no detections), 123.6ms
# image 11/99 /content/circle_dataset/images/test/image_0141.png: 256x256 (no detections), 116.8ms
# image 12/99 /content/circle_dataset/images/test/image_0168.png: 256x256 (no detections), 121.1ms
# image 13/99 /content/circle_dataset/images/test/image_0192.png: 256x256 (no detections), 78.5ms
# image 14/99 /content/circle_dataset/images/test/image_0199.png: 256x256 (no detections), 73.1ms
# image 15/99 /content/circle_dataset/images/test/image_0209.png: 256x256 (no detections), 77.1ms
# image 16/99 /content/circle_dataset/images/test/image_0210.png: 256x256 (no detections), 71.5ms
# image 17/99 /content/circle_dataset/images/test/image_0213.png: 256x256 (no detections), 77.6ms
# image 18/99 /content/circle_dataset/images/test/image_0218.png: 256x256 (no detections), 86.5ms
# image 19/99 /content/circle_dataset/images/test/image_0227.png: 256x256 (no detections), 104.4ms
# image 20/99 /content/circle_dataset/images/test/image_0235.png: 256x256 (no detections), 76.7ms
# image 21/99 /content/circle_dataset/images/test/image_0237.png: 256x256 (no detections), 72.5ms
# image 22/99 /content/circle_dataset/images/test/image_0239.png: 256x256 (no detections), 78.2ms
# image 23/99 /content/circle_dataset/images/test/image_0244.png: 256x256 (no detections), 71.7ms
# image 24/99 /content/circle_dataset/images/test/image_0275.png: 256x256 (no detections), 77.0ms
# image 25/99 /content/circle_dataset/images/test/image_0277.png: 256x256 (no detections), 78.2ms
# image 26/99 /content/circle_dataset/images/test/image_0280.png: 256x256 (no detections), 73.6ms
# image 27/99 /content/circle_dataset/images/test/image_0286.png: 256x256 (no detections), 81.7ms
# image 28/99 /content/circle_dataset/images/test/image_0289.png: 256x256 (no detections), 72.4ms
# image 29/99 /content/circle_dataset/images/test/image_0294.png: 256x256 (no detections), 72.6ms
# image 30/99 /content/circle_dataset/images/test/image_0296.png: 256x256 (no detections), 77.7ms
# image 31/99 /content/circle_dataset/images/test/image_0307.png: 256x256 (no detections), 74.3ms
# image 32/99 /content/circle_dataset/images/test/image_0312.png: 256x256 (no detections), 98.9ms
# image 33/99 /content/circle_dataset/images/test/image_0318.png: 256x256 (no detections), 80.0ms
# image 34/99 /content/circle_dataset/images/test/image_0319.png: 256x256 (no detections), 73.3ms
# image 35/99 /content/circle_dataset/images/test/image_0331.png: 256x256 (no detections), 71.8ms
# image 36/99 /content/circle_dataset/images/test/image_0332.png: 256x256 (no detections), 86.5ms
# image 37/99 /content/circle_dataset/images/test/image_0333.png: 256x256 (no detections), 72.6ms
# image 38/99 /content/circle_dataset/images/test/image_0344.png: 256x256 (no detections), 74.1ms
# image 39/99 /content/circle_dataset/images/test/image_0346.png: 256x256 (no detections), 78.4ms
# image 40/99 /content/circle_dataset/images/test/image_0351.png: 256x256 (no detections), 72.2ms
# image 41/99 /content/circle_dataset/images/test/image_0355.png: 256x256 (no detections), 76.2ms
# image 42/99 /content/circle_dataset/images/test/image_0359.png: 256x256 (no detections), 82.8ms
# image 43/99 /content/circle_dataset/images/test/image_0363.png: 256x256 (no detections), 79.5ms
# image 44/99 /content/circle_dataset/images/test/image_0371.png: 256x256 (no detections), 86.2ms
# image 45/99 /content/circle_dataset/images/test/image_0377.png: 256x256 (no detections), 83.1ms
# image 46/99 /content/circle_dataset/images/test/image_0382.png: 256x256 (no detections), 71.7ms
# image 47/99 /content/circle_dataset/images/test/image_0428.png: 256x256 (no detections), 72.1ms
# image 48/99 /content/circle_dataset/images/test/image_0468.png: 256x256 (no detections), 79.3ms
# image 49/99 /content/circle_dataset/images/test/image_0481.png: 256x256 (no detections), 76.8ms
# image 50/99 /content/circle_dataset/images/test/image_0494.png: 256x256 (no detections), 73.0ms
# image 51/99 /content/circle_dataset/images/test/image_0499.png: 256x256 (no detections), 83.6ms
# image 52/99 /content/circle_dataset/images/test/image_0513.png: 256x256 (no detections), 76.7ms
# image 53/99 /content/circle_dataset/images/test/image_0519.png: 256x256 (no detections), 73.0ms
# image 54/99 /content/circle_dataset/images/test/image_0522.png: 256x256 (no detections), 73.9ms
# image 55/99 /content/circle_dataset/images/test/image_0523.png: 256x256 (no detections), 73.7ms
# image 56/99 /content/circle_dataset/images/test/image_0534.png: 256x256 (no detections), 82.3ms
# image 57/99 /content/circle_dataset/images/test/image_0536.png: 256x256 (no detections), 70.1ms
# image 58/99 /content/circle_dataset/images/test/image_0544.png: 256x256 (no detections), 75.5ms
# image 59/99 /content/circle_dataset/images/test/image_0557.png: 256x256 (no detections), 74.4ms
# image 60/99 /content/circle_dataset/images/test/image_0575.png: 256x256 (no detections), 75.6ms
# image 61/99 /content/circle_dataset/images/test/image_0583.png: 256x256 (no detections), 72.4ms
# image 62/99 /content/circle_dataset/images/test/image_0584.png: 256x256 (no detections), 73.1ms
# image 63/99 /content/circle_dataset/images/test/image_0589.png: 256x256 (no detections), 79.9ms
# image 64/99 /content/circle_dataset/images/test/image_0590.png: 256x256 (no detections), 76.7ms
# image 65/99 /content/circle_dataset/images/test/image_0617.png: 256x256 (no detections), 76.6ms
# image 66/99 /content/circle_dataset/images/test/image_0626.png: 256x256 (no detections), 72.6ms
# image 67/99 /content/circle_dataset/images/test/image_0635.png: 256x256 (no detections), 73.5ms
# image 68/99 /content/circle_dataset/images/test/image_0650.png: 256x256 (no detections), 72.2ms
# image 69/99 /content/circle_dataset/images/test/image_0652.png: 256x256 (no detections), 90.4ms
# image 70/99 /content/circle_dataset/images/test/image_0656.png: 256x256 (no detections), 72.6ms
# image 71/99 /content/circle_dataset/images/test/image_0662.png: 256x256 (no detections), 73.0ms
# image 72/99 /content/circle_dataset/images/test/image_0668.png: 256x256 (no detections), 73.6ms
# image 73/99 /content/circle_dataset/images/test/image_0677.png: 256x256 (no detections), 73.1ms
# image 74/99 /content/circle_dataset/images/test/image_0678.png: 256x256 (no detections), 71.9ms
# image 75/99 /content/circle_dataset/images/test/image_0697.png: 256x256 (no detections), 77.5ms
# image 76/99 /content/circle_dataset/images/test/image_0734.png: 256x256 (no detections), 78.8ms
# image 77/99 /content/circle_dataset/images/test/image_0741.png: 256x256 (no detections), 71.4ms
# image 78/99 /content/circle_dataset/images/test/image_0797.png: 256x256 (no detections), 74.7ms
# image 79/99 /content/circle_dataset/images/test/image_0798.png: 256x256 (no detections), 73.9ms
# image 80/99 /content/circle_dataset/images/test/image_0800.png: 256x256 (no detections), 81.4ms
# image 81/99 /content/circle_dataset/images/test/image_0811.png: 256x256 (no detections), 79.6ms
# image 82/99 /content/circle_dataset/images/test/image_0816.png: 256x256 (no detections), 85.6ms
# image 83/99 /content/circle_dataset/images/test/image_0820.png: 256x256 (no detections), 72.6ms
# image 84/99 /content/circle_dataset/images/test/image_0822.png: 256x256 (no detections), 74.7ms
# image 85/99 /content/circle_dataset/images/test/image_0823.png: 256x256 (no detections), 80.9ms
# image 86/99 /content/circle_dataset/images/test/image_0865.png: 256x256 (no detections), 77.0ms
# image 87/99 /content/circle_dataset/images/test/image_0883.png: 256x256 (no detections), 73.2ms
# image 88/99 /content/circle_dataset/images/test/image_0893.png: 256x256 (no detections), 78.4ms
# image 89/99 /content/circle_dataset/images/test/image_0896.png: 256x256 (no detections), 72.0ms
# image 90/99 /content/circle_dataset/images/test/image_0899.png: 256x256 (no detections), 78.7ms
# image 91/99 /content/circle_dataset/images/test/image_0907.png: 256x256 (no detections), 73.9ms
# image 92/99 /content/circle_dataset/images/test/image_0917.png: 256x256 (no detections), 72.7ms
# image 93/99 /content/circle_dataset/images/test/image_0924.png: 256x256 (no detections), 73.8ms
# image 94/99 /content/circle_dataset/images/test/image_0941.png: 256x256 (no detections), 74.1ms
# image 95/99 /content/circle_dataset/images/test/image_0950.png: 256x256 (no detections), 78.7ms
# image 96/99 /content/circle_dataset/images/test/image_0963.png: 256x256 (no detections), 75.3ms
# image 97/99 /content/circle_dataset/images/test/image_0977.png: 256x256 (no detections), 76.0ms
# image 98/99 /content/circle_dataset/images/test/image_0989.png: 256x256 (no detections), 71.9ms
# image 99/99 /content/circle_dataset/images/test/image_0994.png: 256x256 (no detections), 76.3ms
# Speed: 0.3ms pre-process, 83.2ms inference, 0.2ms NMS per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/exp4
# 0 labels saved to runs/detect/exp4/labels

# %% [markdown]
# Step 9: Save and Document the Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_path = '/content/drive/MyDrive/YOLOv5/circle_detection'

# %%
import os

os.makedirs(save_path, exist_ok=True)

# %%
# save theBest Weights to Google Drive
# !cp runs/train/circle_detection/weights/best.pt /content/drive/MyDrive/YOLOv5/circle_detection/best.pt
